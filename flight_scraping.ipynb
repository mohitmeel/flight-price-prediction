# %%
import selenium
from selenium import webdriver
import pandas as pd
import warnings
warnings.filterwarnings('ignore')
import time
from selenium.webdriver.common.keys import Keys

# %%
driver=webdriver.Chrome('chromedriver.exe')

# %%
url='https://paytm.com/flights'
driver.get(url)

# %%
source=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div/div[2]/div[2]/div[1]/div[1]/input')
source
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="1eb6ea08-6f15-442b-8a62-18bccfedf0a8")>

# %%
source.click()

# %%
newdelhi=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div/div[2]/div[2]/div[1]/div[2]/div/div/div[2]/div/div/div[1]/div[2]')
newdelhi
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="0c0cf5b5-f69b-437d-98da-7802dda13676")>

# %%
newdelhi.click()

# %%
des=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div/div[2]/div[4]/div[1]/div[1]/input')
des
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="8f3916f0-1fc3-4f3c-87b8-9c46bdad0593")>

# %%
des.click()

# %%
mumbai=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div/div[2]/div[4]/div[1]/div[2]/div/div/div[4]/div/div/div[1]/div[2]')
mumbai
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="e58d013a-888e-438a-9e67-d4fd4e604eff")>

# %%
mumbai.click()

# %%
date=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div/div[2]/div[5]/div/div/div/div/div/div/input')
date
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="7f73b900-b69b-4149-8bb0-81c3e32fb230")>

# %%
date.click()

# %%
date=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div/div[2]/div[5]/div/div/div/div/div[2]/div/div[2]/table/tbody/tr[4]/td[4]/div/div')
date
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="e997a440-9c44-43cf-9443-376c73a1ac17")>

# %%
date.click()

# %%
search=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div[2]/div/div[1]/div/div/div[2]/div[8]/div/button')
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="54c1534d-86d1-4e72-a83b-c948ba2a4ce5")>

# %%
search.click()

# %%
airline=driver.find_elements_by_xpath('//div[@class="_3H-S _1Eia"]')
airline[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="45705880-3a8e-4865-9117-00b215c5d476")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="8d348e3a-0cea-4ce6-8fa9-f08274f6da05")>]

# %%
airlines=[]
for i in airline:
    airlines.append(i.text)
airlines
# Out:
# ['IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
len(airlines)
# Out:
# 213

# %%
deptime=driver.find_elements_by_xpath('//div[@class="_3Lds _1OV0"]')
deptime[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="e907b0b6-f828-4468-bf7c-cf6cb6cc21da")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="daa78104-42ef-42a5-a917-dd2e77b2885e")>]

# %%
deptimes=[]
for i in deptime:
    deptimes.append(i.text.split()[0])
deptimes
# Out:
# ['11:55',
#  '21:30',
#  '23:35',
#  '06:30',
#  '10:45',
#  '17:00',
#  '04:25',
#  '14:00',
#  '18:30',
#  '06:00',
#  '15:25',
#  '16:15',
#  '05:30',
#  '14:10',
#  '19:45',
#  '12:50',
#  '20:40',
#  '14:20',
#  '15:30',
#  '22:45',
#  '10:55',
#  '17:45',
#  '08:45',
#  '07:20',
#  '21:40',
#  '19:45',
#  '10:20',
#  '08:00',
#  '16:45',
#  '11:40',
#  '21:45',
#  '09:35',
#  '20:55',
#  '05:55',
#  '06:15',
#  '05:20',
#  '13:35',
#  '06:25',
#  '05:55',
#  '05:00',
#  '06:25',
#  '12:35',
#  '20:30',
#  '05:55',
#  '20:05',
#  '08:45',
#  '18:45',
#  '16:35',
#  '14:50',
#  '16:35',
#  '14:50',
#  '07:00',
#  '20:00',
#  '08:00',
#  '19:00',
#  '14:00',
#  '21:15',
#  '10:00',
#  '15:00',
#  '17:55',
#  '21:40',
#  '09:35',
#  '18:10',
#  '18:10',
#  '05:55',
#  '09:30',
#  '08:50',
#  '21:20',
#  '20:55',
#  '19:45',
#  '17:45',
#  '06:30',
#  '13:00',
#  '07:30',
#  '18:55',
#  '18:10',
#  '06:30',
#  '08:10',
#  '21:20',
#  '18:10',
#  '08:30',
#  '07:20',
#  '12:50',
# ...

# %%
dep=[]
for i in deptime:
    dep.append(i.text.split()[1])
dep
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
arrtime=driver.find_elements_by_xpath('//div[@class="_3H-S _1wD5"]')
arrtime[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="6f663f97-569a-4648-8314-ef482e4528d5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="2b6e2400-1994-43a9-b490-f992a5a2c996")>]

# %%
arrtimes=[]
for i in arrtime:
    arrtimes.append(i.text.split()[0])
arrtimes
# Out:
# ['13:55',
#  '23:30',
#  '01:40',
#  '08:35',
#  '12:50',
#  '19:05',
#  '06:35',
#  '16:10',
#  '20:40',
#  '08:10',
#  '17:35',
#  '18:25',
#  '07:40',
#  '16:20',
#  '21:55',
#  '15:00',
#  '22:50',
#  '16:30',
#  '17:40',
#  '01:00',
#  '13:10',
#  '20:00',
#  '11:00',
#  '09:35',
#  '23:55',
#  '22:00',
#  '12:35',
#  '10:20',
#  '19:05',
#  '14:00',
#  '00:10',
#  '12:00',
#  '23:25',
#  '10:20',
#  '10:55',
#  '10:45',
#  '19:40',
#  '13:25',
#  '15:00',
#  '14:20',
#  '16:10',
#  '22:30',
#  '10:05',
#  '19:40',
#  '10:20',
#  '23:55',
#  '10:45',
#  '13:35',
#  '13:35',
#  '16:10',
#  '16:10',
#  '09:05',
#  '22:10',
#  '10:10',
#  '21:15',
#  '16:15',
#  '23:35',
#  '12:35',
#  '18:15',
#  '22:10',
#  '07:15',
#  '20:40',
#  '06:15',
#  '20:25',
#  '07:55',
#  '11:35',
#  '11:10',
#  '06:15',
#  '09:55',
#  '21:55',
#  '20:05',
#  '06:15',
#  '14:50',
#  '09:45',
#  '21:15',
#  '23:05',
#  '23:05',
#  '20:40',
#  '09:40',
#  '09:40',
#  '15:55',
#  '15:55',
#  '19:15',
# ...

# %%
arr=[]
for i in arrtime:
    arr.append(i.text.split()[1])
arr
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
dur=driver.find_elements_by_xpath('//div[@class="_3zzl _1OV0"]')
dur[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="729e24c6-14ae-41e6-93ba-b6082cf4fcca")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="2bc48e60-4604-47e9-aae4-bdfe1d03a3a4")>]

# %%
durs=[]
for i in dur:
    durs.append(i.text.split()[0:2])
durs
# Out:
# [['2h', 'Non'],
#  ['2h', 'Non'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '25m'],
#  ['2h', '25m'],
#  ['2h', '30m'],
#  ['4h', '25m'],
#  ['4h', '40m'],
#  ['5h', '25m'],
#  ['6h', '5m'],
#  ['7h', '1'],
#  ['9h', '5m'],
#  ['9h', '20m'],
#  ['9h', '45m'],
#  ['9h', '55m'],
#  ['13h', '35m'],
#  ['13h', '45m'],
#  ['14h', '15m'],
#  ['15h', '10m'],
#  ['16h', '1'],
#  ['21h', '1'],
#  ['22h', '45m'],
#  ['23h', '35m'],
#  ['25h', '20m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
# ...

# %%
stop=[]
for i in dur:
    stop.append(i.text.split()[2:])
stop
# Out:
# [['Stop'],
#  ['Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['1', 'stop', 'at', 'Ahmedabad'],
#  ['1', 'stop', 'at', 'Jabalpur'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Ahmedabad'],
#  ['stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Ahmedabad'],
#  ['1', 'stop', 'at', 'Amritsar'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Patna'],
# ...

# %%
price=driver.find_elements_by_xpath('//div[@class="_2gMo"]')
price[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="03677809-5886-4942-87de-e0f1cb0be6e0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="b58c06c6-8aea-4c71-90b0-b2ad6e637015")>]

# %%
prices=[]
for i in price:
    prices.append(i.text)
prices
# Out:
# ['8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,581',
#  '8,581',
#  '8,715',
#  '8,789',
#  '8,896',
#  '8,896',
#  '8,896',
#  '9,032',
#  '9,086',
#  '9,316',
#  '9,316',
#  '9,452',
#  '9,661',
#  '9,841',
#  '9,841',
#  '9,977',
#  '9,977',
#  '10,210',
#  '10,502',
#  '10,502',
#  '10,522',
#  '10,522',
# ...

# %%
date1=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/div[2]/div/div[1]/div[1]/div/div/div[2]/a[3]')
date1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="2ce47b3c-216a-414f-97e3-cf1c80731be3")>

# %%
date1.click()

# %%
airline1=driver.find_elements_by_xpath('//div[@class="_3H-S _1Eia"]')
airline1[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="79106d46-3854-44f2-b0fb-e52ef9dd61c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="77ff6621-4f2f-4f4f-ba30-85e0c005c052")>]

# %%
airlines1=[]
for i in airline1:
    airlines1.append(i.text)
airlines
# Out:
# ['IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
len(airlines1)
# Out:
# 196

# %%
deptime1=driver.find_elements_by_xpath('//div[@class="_3Lds _1OV0"]')
deptime1[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="8e4237a2-ca6b-486d-a623-b5805e6ccfd5")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="9551ab08-f67c-4403-8be6-96e704987cec")>]

# %%
deptimes1=[]
for i in deptime1:
    deptimes1.append(i.text.split()[0])
deptimes1
# Out:
# ['06:05',
#  '11:55',
#  '05:55',
#  '06:30',
#  '23:35',
#  '17:00',
#  '07:20',
#  '10:45',
#  '09:30',
#  '04:25',
#  '14:00',
#  '06:00',
#  '20:45',
#  '14:10',
#  '15:25',
#  '16:15',
#  '19:00',
#  '14:20',
#  '15:30',
#  '12:50',
#  '10:55',
#  '18:50',
#  '22:45',
#  '08:45',
#  '07:20',
#  '07:30',
#  '10:20',
#  '08:00',
#  '08:50',
#  '16:45',
#  '11:40',
#  '21:45',
#  '09:35',
#  '20:55',
#  '06:15',
#  '05:20',
#  '05:20',
#  '11:30',
#  '10:30',
#  '11:30',
#  '05:00',
#  '20:30',
#  '05:50',
#  '20:00',
#  '08:45',
#  '06:25',
#  '18:45',
#  '16:55',
#  '14:50',
#  '14:50',
#  '07:00',
#  '08:00',
#  '21:15',
#  '10:00',
#  '15:00',
#  '07:25',
#  '21:40',
#  '21:00',
#  '09:35',
#  '09:35',
#  '08:10',
#  '08:10',
#  '18:10',
#  '20:00',
#  '19:00',
#  '17:55',
#  '18:55',
#  '17:45',
#  '19:45',
#  '13:00',
#  '19:45',
#  '19:45',
#  '10:40',
#  '10:40',
#  '14:00',
#  '21:30',
#  '07:20',
#  '08:30',
#  '07:20',
#  '13:00',
#  '18:45',
#  '05:45',
#  '14:45',
# ...

# %%
dep1=[]
for i in deptime1:
    dep1.append(i.text.split()[1])
dep1
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
arrtime1=driver.find_elements_by_xpath('//div[@class="_3H-S _1wD5"]')
arrtime1[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="3171e737-abcd-4baa-9faf-deab31ff4e29")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="55f630ff-ae25-448a-a509-5dcf67584191")>]

# %%
arrtimes1=[]
for i in arrtime1:
    arrtimes1.append(i.text.split()[0])
arrtimes1
# Out:
# ['21:20',
#  '13:55',
#  '07:55',
#  '08:35',
#  '01:40',
#  '19:05',
#  '09:25',
#  '12:50',
#  '11:35',
#  '06:35',
#  '16:10',
#  '08:10',
#  '22:55',
#  '16:20',
#  '17:35',
#  '18:25',
#  '21:10',
#  '16:30',
#  '17:40',
#  '15:00',
#  '13:10',
#  '21:05',
#  '01:00',
#  '11:00',
#  '09:35',
#  '09:45',
#  '12:35',
#  '10:20',
#  '11:10',
#  '19:05',
#  '14:00',
#  '00:10',
#  '12:00',
#  '23:25',
#  '10:55',
#  '10:45',
#  '11:30',
#  '18:00',
#  '17:50',
#  '18:55',
#  '14:20',
#  '10:05',
#  '19:30',
#  '10:30',
#  '23:55',
#  '21:45',
#  '10:45',
#  '10:55',
#  '13:35',
#  '16:10',
#  '09:05',
#  '10:10',
#  '23:35',
#  '12:35',
#  '18:15',
#  '14:05',
#  '07:15',
#  '07:15',
#  '20:40',
#  '21:20',
#  '20:40',
#  '21:20',
#  '20:25',
#  '22:10',
#  '21:15',
#  '22:10',
#  '21:15',
#  '20:05',
#  '22:00',
#  '14:50',
#  '21:55',
#  '21:55',
#  '19:15',
#  '23:45',
#  '16:15',
#  '23:30',
#  '12:05',
#  '15:55',
#  '15:55',
#  '21:50',
#  '00:05',
#  '12:50',
#  '00:05',
# ...

# %%
arr1=[]
for i in arrtime1:
    arr1.append(i.text.split()[1])
arr1
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
dur1=driver.find_elements_by_xpath('//div[@class="_3zzl _1OV0"]')
dur1[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="212d6c83-6efe-4551-aaa2-7c22b7337ce1")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="4ef215ac-5c1c-4999-a7fb-4d6973df0156")>]

# %%
durs1=[]
for i in dur1:
    durs1.append(i.text.split()[0:2])
durs1
# Out:
# [['15h', '15m'],
#  ['2h', 'Non'],
#  ['2h', 'Non'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '25m'],
#  ['2h', '25m'],
#  ['2h', '30m'],
#  ['4h', '40m'],
#  ['5h', '25m'],
#  ['6h', '10m'],
#  ['6h', '30m'],
#  ['7h', '20m'],
#  ['7h', '25m'],
#  ['9h', '20m'],
#  ['13h', '35m'],
#  ['13h', '40m'],
#  ['14h', '30m'],
#  ['15h', '10m'],
#  ['15h', '20m'],
#  ['16h', '1'],
#  ['18h', '1'],
#  ['22h', '45m'],
#  ['25h', '20m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '20m'],
#  ['2h', '35m'],
#  ['3h', '15m'],
# ...

# %%
stop1=[]
for i in dur1:
    stop1.append(i.text.split()[2:])
stop1
# Out:
# [['2', 'Stops', '(VTZ,', 'BLR)'],
#  ['Stop'],
#  ['Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['1', 'stop', 'at', 'Jabalpur'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Darbhanga'],
#  ['1', 'stop', 'at', 'Varanasi'],
#  ['1', 'stop', 'at', 'Darbhanga'],
#  ['1', 'stop', 'at', 'Amritsar'],
#  ['1', 'stop', 'at', 'Bengaluru'],
# ...

# %%
price1=driver.find_elements_by_xpath('//div[@class="_2gMo"]')
price1[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="1eab91ce-6ea8-4791-b34f-a3a34eb8bfac")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="5eadf82b-bee5-43d8-bc3e-78061c400ae8")>]

# %%
prices1=[]
for i in price1:
    prices1.append(i.text)
prices1
# Out:
# ['8,052',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,789',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,896',
#  '8,896',
#  '8,999',
#  '9,135',
#  '9,316',
#  '9,629',
#  '9,708',
#  '9,708',
#  '9,840',
#  '10,366',
#  '10,522',
#  '10,522',
#  '10,522',
#  '10,522',
#  '10,942',
#  '10,942',
# ...

# %%
date2=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/div[2]/div/div[1]/div[1]/div/div/div[2]/a[4]')
date2
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="76cf8bf0-5d3b-4399-817e-99d4b253ad83")>

# %%
date2.click()

# %%
airline2=driver.find_elements_by_xpath('//div[@class="_3H-S _1Eia"]')
airline2[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="0499b910-694c-44e1-bf85-aca9a153096e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="7aae3e83-4c59-4149-b955-1df46495362c")>]

# %%
airlines2=[]
for i in airline2:
    airlines2.append(i.text)
airlines2
# Out:
# ['Air Asia',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
# ...

# %%
deptime2=driver.find_elements_by_xpath('//div[@class="_3Lds _1OV0"]')
deptime2[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="122c7ca8-93ac-476d-ac07-5ceb317f6a18")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="12054449-4dbe-4bf5-8826-cf55432f28d3")>]

# %%
deptimes2=[]
for i in deptime2:
    deptimes2.append(i.text.split()[0])
deptimes2
# Out:
# ['06:05',
#  '11:55',
#  '05:55',
#  '21:30',
#  '06:30',
#  '17:00',
#  '07:20',
#  '10:45',
#  '23:35',
#  '09:30',
#  '04:25',
#  '20:45',
#  '06:00',
#  '14:00',
#  '14:10',
#  '15:25',
#  '02:00',
#  '16:15',
#  '19:45',
#  '19:00',
#  '15:30',
#  '14:20',
#  '12:50',
#  '20:40',
#  '07:00',
#  '18:45',
#  '22:45',
#  '10:55',
#  '18:10',
#  '08:45',
#  '07:20',
#  '19:45',
#  '10:20',
#  '07:30',
#  '08:00',
#  '18:55',
#  '16:45',
#  '11:40',
#  '17:45',
#  '21:45',
#  '20:55',
#  '05:55',
#  '06:15',
#  '05:20',
#  '15:30',
#  '11:30',
#  '11:30',
#  '10:40',
#  '05:55',
#  '10:40',
#  '05:00',
#  '05:20',
#  '10:30',
#  '09:55',
#  '05:20',
#  '20:05',
#  '18:25',
#  '20:00',
#  '10:40',
#  '08:45',
#  '06:25',
#  '18:45',
#  '16:55',
#  '08:45',
#  '09:45',
#  '21:15',
#  '07:25',
#  '21:40',
#  '21:00',
#  '08:10',
#  '08:10',
#  '21:20',
#  '21:20',
#  '06:30',
#  '06:30',
#  '07:00',
#  '08:00',
#  '20:00',
#  '19:00',
#  '14:00',
#  '10:00',
#  '17:55',
#  '19:45',
# ...

# %%
dep2=[]
for i in deptime2:
    dep2.append(i.text.split()[1])
dep2
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
arrtime2=driver.find_elements_by_xpath('//div[@class="_3H-S _1wD5"]')
arrtime2[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="3aa2e340-03a2-4538-85e5-61bb79231a24")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="c0b08d39-0a1b-42be-913f-52f373335f2c")>]

# %%
arrtimes2=[]
for i in arrtime2:
    arrtimes2.append(i.text.split()[0])
arrtimes2
# Out:
# ['21:20',
#  '13:55',
#  '07:55',
#  '23:30',
#  '08:35',
#  '19:05',
#  '09:25',
#  '12:50',
#  '01:40',
#  '11:35',
#  '06:35',
#  '22:55',
#  '08:10',
#  '16:10',
#  '16:20',
#  '17:35',
#  '04:10',
#  '18:25',
#  '21:55',
#  '21:10',
#  '17:40',
#  '16:30',
#  '15:00',
#  '22:50',
#  '09:15',
#  '21:00',
#  '01:00',
#  '13:10',
#  '20:25',
#  '11:00',
#  '09:35',
#  '22:00',
#  '12:35',
#  '09:45',
#  '10:20',
#  '21:15',
#  '19:05',
#  '14:00',
#  '20:05',
#  '00:10',
#  '23:25',
#  '10:20',
#  '10:55',
#  '10:45',
#  '21:45',
#  '18:00',
#  '18:55',
#  '18:40',
#  '15:00',
#  '19:50',
#  '14:20',
#  '16:00',
#  '21:20',
#  '21:00',
#  '18:25',
#  '10:20',
#  '08:55',
#  '10:30',
#  '01:20',
#  '23:55',
#  '21:45',
#  '10:45',
#  '10:55',
#  '08:55',
#  '11:20',
#  '23:35',
#  '14:05',
#  '07:15',
#  '07:15',
#  '20:40',
#  '21:20',
#  '06:15',
#  '09:40',
#  '23:05',
#  '06:15',
#  '09:05',
#  '10:10',
#  '22:10',
#  '21:15',
#  '16:15',
#  '12:35',
#  '22:10',
#  '21:55',
# ...

# %%
arr2=[]
for i in arrtime2:
    arr2.append(i.text.split()[1])
arr2
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
dur2=driver.find_elements_by_xpath('//div[@class="_3zzl _1OV0"]')
dur2[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="c23657ee-b056-472b-a94a-6a3f210ed768")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="d811ee6f-751c-4e6a-9ca2-6b34dd146044")>]

# %%
durs2=[]
for i in dur2:
    durs2.append(i.text.split()[0:2])
dur2
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="c23657ee-b056-472b-a94a-6a3f210ed768")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="d811ee6f-751c-4e6a-9ca2-6b34dd146044")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="8fdf7f68-d292-4fac-b249-12d84716c891")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="131384dc-8583-4695-8357-cc7771bc9200")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="3a69e518-072e-4dac-95bf-4917fb60e516")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="1b5dd58f-aecd-4566-8be7-336f9f677062")>,
# ...

# %%
stop2=[]
for i in dur2:
    stop2.append(i.text.split()[2:])
stop2
# Out:
# [['2', 'Stops', '(VTZ,', 'BLR)'],
#  ['Stop'],
#  ['Stop'],
#  ['Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['1', 'stop', 'at', 'Ahmedabad'],
#  ['1', 'stop', 'at', 'Jabalpur'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Varanasi'],
#  ['1', 'stop', 'at', 'Darbhanga'],
# ...

# %%
price2=driver.find_elements_by_xpath('//div[@class="_2gMo"]')
price2[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="0f444070-9f26-4c66-b1a2-d4b2736e7c3e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="ab68b015-3bbd-4ef9-aaea-806ef5ec05ec")>]

# %%
prices2=[]
for i in price2:
    prices2.append(i.text)
prices2
# Out:
# ['8,052',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,580',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,715',
#  '8,715',
#  '8,715',
#  '8,715',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,896',
# ...

# %%
date3=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/div[2]/div/div[1]/div[1]/div/div/div[2]/a[5]')
date3
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="e5e294ab-dbb6-4c78-8035-4610344a4ce7")>

# %%
date3.click()

# %%
airline3=driver.find_elements_by_xpath('//div[@class="_3H-S _1Eia"]')
airline3[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="ee7010bd-b248-47d7-914c-96cee0a0781e")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="f7f035d8-206e-4427-9fef-fb3645b3e611")>]

# %%
airlines3=[]
for i in airline3:
    airlines3.append(i.text)
airlines3
# Out:
# ['Air Asia',
#  'Air Asia',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air India',
#  'Air India',
#  'Air India',
# ...

# %%
len(airlines3)
# Out:
# 199

# %%
deptime3=driver.find_elements_by_xpath('//div[@class="_3Lds _1OV0"]')
deptime3[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="10056213-c55e-4f35-95bb-b0f50918d740")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="d8cee2f4-4979-47aa-89e4-8144be51b329")>]

# %%
deptimes3=[]
for i in deptime3:
    deptimes3.append(i.text.split()[0])
deptimes3
# Out:
# ['06:05',
#  '13:00',
#  '11:55',
#  '23:35',
#  '10:45',
#  '07:20',
#  '06:30',
#  '17:00',
#  '09:30',
#  '04:25',
#  '06:00',
#  '02:40',
#  '14:00',
#  '19:50',
#  '02:00',
#  '19:45',
#  '16:15',
#  '15:25',
#  '14:10',
#  '19:00',
#  '20:40',
#  '10:55',
#  '22:45',
#  '07:00',
#  '18:10',
#  '08:45',
#  '19:45',
#  '07:20',
#  '21:40',
#  '10:20',
#  '07:30',
#  '08:00',
#  '08:50',
#  '21:45',
#  '20:55',
#  '05:55',
#  '06:15',
#  '05:20',
#  '05:55',
#  '11:30',
#  '11:30',
#  '12:50',
#  '05:00',
#  '11:15',
#  '05:20',
#  '09:55',
#  '20:00',
#  '10:40',
#  '08:45',
#  '06:25',
#  '16:55',
#  '18:55',
#  '09:45',
#  '21:15',
#  '07:25',
#  '10:40',
#  '21:40',
#  '21:00',
#  '09:35',
#  '20:00',
#  '09:35',
#  '08:10',
#  '10:40',
#  '08:10',
#  '22:20',
#  '20:00',
#  '14:00',
#  '19:00',
#  '10:00',
#  '14:30',
#  '17:55',
#  '19:45',
#  '18:45',
#  '18:10',
#  '20:55',
#  '14:20',
#  '15:30',
#  '12:50',
#  '11:40',
#  '17:45',
#  '18:55',
#  '16:45',
#  '21:30',
# ...

# %%
dep3=[]
for i in deptime3:
    dep3.append(i.text.split()[1])
dep3
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
arrtime3=driver.find_elements_by_xpath('//div[@class="_3H-S _1wD5"]')
arrtime3[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="976ef839-eedc-485c-9fe0-8a7f08f68649")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="d99a8f58-8be9-417d-a843-a16e3a44dfef")>]

# %%
arrtimes3=[]
for i in arrtime3:
    arrtimes3.append(i.text.split()[0])
arrtimes3
# Out:
# ['21:20',
#  '14:50',
#  '13:55',
#  '01:40',
#  '12:50',
#  '09:25',
#  '08:35',
#  '19:05',
#  '11:35',
#  '06:35',
#  '08:10',
#  '04:50',
#  '16:10',
#  '22:00',
#  '04:10',
#  '21:55',
#  '18:25',
#  '17:35',
#  '16:20',
#  '21:10',
#  '22:50',
#  '13:10',
#  '01:00',
#  '09:15',
#  '20:25',
#  '11:00',
#  '22:00',
#  '09:35',
#  '23:55',
#  '12:35',
#  '09:45',
#  '10:20',
#  '11:10',
#  '00:10',
#  '23:25',
#  '10:20',
#  '10:55',
#  '10:45',
#  '12:10',
#  '18:00',
#  '18:55',
#  '21:00',
#  '14:20',
#  '21:20',
#  '16:00',
#  '21:00',
#  '10:30',
#  '01:20',
#  '23:55',
#  '21:45',
#  '10:55',
#  '13:40',
#  '11:20',
#  '23:35',
#  '14:05',
#  '19:15',
#  '07:15',
#  '07:15',
#  '20:40',
#  '07:05',
#  '21:20',
#  '20:40',
#  '23:45',
#  '21:20',
#  '12:25',
#  '22:10',
#  '16:15',
#  '21:15',
#  '12:35',
#  '18:10',
#  '22:10',
#  '21:55',
#  '21:00',
#  '23:05',
#  '09:55',
#  '16:30',
#  '17:40',
#  '15:00',
#  '14:00',
#  '20:05',
#  '21:15',
#  '19:05',
#  '23:30',
# ...

# %%
arr3=[]
for i in arrtime3:
    arr3.append(i.text.split()[1])
arr3
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
dur3=driver.find_elements_by_xpath('//div[@class="_3zzl _1OV0"]')
dur3[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="7d2c5d12-b23d-4036-bd6e-3ecc904aaaea")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="07090a37-9578-40c5-a440-73dd32b1579d")>]

# %%
durs3=[]
for i in dur3:
    durs3.append(i.text.split()[0:2])
durs3
# Out:
# [['15h', '15m'],
#  ['1h', '50m'],
#  ['2h', 'Non'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '25m'],
#  ['2h', '30m'],
#  ['4h', '25m'],
#  ['4h', '40m'],
#  ['5h', '25m'],
#  ['6h', '15m'],
#  ['6h', '30m'],
#  ['7h', '25m'],
#  ['8h', '10m'],
#  ['9h', '20m'],
#  ['10h', '5m'],
#  ['10h', '40m'],
#  ['11h', '5m'],
#  ['14h', '30m'],
#  ['14h', '40m'],
#  ['15h', '10m'],
#  ['15h', '20m'],
#  ['18h', '1'],
#  ['18h', '45m'],
#  ['25h', '35m'],
#  ['2h', '20m'],
#  ['6h', '40m'],
# ...

# %%
stop3=[]
for i in dur3:
    stop3.append(i.text.split()[2:])
stop3
# Out:
# [['2', 'Stops', '(VTZ,', 'BLR)'],
#  ['Non', 'Stop'],
#  ['Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['1', 'stop', 'at', 'Ahmedabad'],
#  ['1', 'stop', 'at', 'Jabalpur'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Ahmedabad'],
#  ['1', 'stop', 'at', 'Darbhanga'],
#  ['1', 'stop', 'at', 'Darbhanga'],
#  ['1', 'stop', 'at', 'Ranchi'],
#  ['1', 'stop', 'at', 'Amritsar'],
# ...

# %%
price3=driver.find_elements_by_xpath('//div[@class="_2gMo"]')
price3[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="a492e442-caae-41f7-b4e2-711711dd905d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="f167a7bf-e4f3-47c3-99cb-099dce487ed5")>]

# %%
prices3=[]
for i in price3:
    prices3.append(i.text)
prices3
# Out:
# ['8,052',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,580',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,581',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,790',
#  '8,896',
#  '8,935',
#  '9,032',
#  '9,086',
#  '9,316',
#  '9,316',
#  '9,316',
#  '9,316',
#  '9,316',
#  '9,316',
#  '9,316',
#  '9,841',
# ...

# %%
returned=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/div[1]/div[2]/div/div/div/div/div[3]/div')
returned
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="adc384f0-c24f-496a-8bbf-ac28ad3c3170")>

# %%
returned.click()

# %%
date=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div/div/div/div/div')
date
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="2db0b4a3-4910-432b-ad83-7747d8dc6ce5")>

# %%
date.click()

# %%
date1=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/div[1]/div[2]/div/div/div/div/div[5]/div/div/div/div/div[2]/div/div[2]/table/tbody/tr[4]/td[4]/div/div')
date1
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="73d9cb3e-9379-4061-8980-79a076f7592d")>

# %%
date1.click()

# %%
search=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/div[1]/div[2]/div/div/div[2]/div/div[8]/div/button')
search
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="6f0ee5d3-0cd8-4cc6-bad7-ca94492968f9")>

# %%
search.click()

# %%
airline4=driver.find_elements_by_xpath('//div[@class="_3H-S _1Eia"]')
airline4[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="95320ec9-091d-4cd8-bfaa-7ab40046bef0")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="c73606b9-f087-4cfd-999f-7a40374cba56")>]

# %%
airlines4=[]
for i in airline4:
    airlines4.append(i.text)
airlines4
# Out:
# ['Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
# ...

# %%
len(airlines4)
# Out:
# 219

# %%
deptime4=driver.find_elements_by_xpath('//div[@class="_3Lds _1OV0"]')
deptime4[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="9f8b937d-e780-4164-a391-030a8e93f81b")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="f2fab619-36e6-4f77-8d92-9fb5a84b787e")>]

# %%
deptimes4=[]
for i in deptime4:
    deptimes4.append(i.text.split()[0])
deptimes4
# Out:
# ['06:00',
#  '20:55',
#  '12:25',
#  '11:55',
#  '22:45',
#  '17:35',
#  '07:30',
#  '10:25',
#  '21:55',
#  '14:40',
#  '15:45',
#  '02:40',
#  '14:35',
#  '07:00',
#  '18:00',
#  '05:55',
#  '12:40',
#  '07:00',
#  '12:05',
#  '18:00',
#  '19:30',
#  '23:30',
#  '06:05',
#  '18:35',
#  '08:30',
#  '14:20',
#  '19:00',
#  '10:55',
#  '20:40',
#  '16:45',
#  '17:10',
#  '15:55',
#  '07:45',
#  '09:25',
#  '07:20',
#  '16:00',
#  '10:00',
#  '20:35',
#  '00:35',
#  '19:35',
#  '15:25',
#  '07:20',
#  '19:10',
#  '10:50',
#  '15:35',
#  '07:05',
#  '04:30',
#  '10:50',
#  '11:50',
#  '10:05',
#  '10:50',
#  '15:40',
#  '04:30',
#  '10:50',
#  '10:50',
#  '10:50',
#  '10:05',
#  '10:50',
#  '12:00',
#  '10:05',
#  '10:50',
#  '07:05',
#  '12:00',
#  '07:05',
#  '19:35',
#  '07:05',
#  '04:30',
#  '05:00',
#  '04:30',
#  '04:30',
#  '04:35',
#  '14:25',
#  '15:35',
#  '10:05',
#  '20:40',
#  '15:40',
#  '21:20',
#  '07:50',
#  '20:40',
#  '22:35',
#  '06:35',
#  '22:35',
#  '06:35',
# ...

# %%
dep4=[]
for i in deptime4:
    dep4.append(i.text.split()[1])
dep4
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
dur4=driver.find_elements_by_xpath('//div[@class="_3zzl _1OV0"]')
dur4[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="aa872463-65af-4165-8d10-0de5d0bd76be")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="15069050-d702-4fc2-a974-1cdabcbd4859")>]

# %%
durs4=[]
for i in dur4:
    durs4.append(i.text.split()[0:2])
durs4
# Out:
# [['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['1h', '55m'],
#  ['2h', 'Non'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '25m'],
#  ['2h', '25m'],
#  ['3h', '45m'],
#  ['3h', '50m'],
#  ['5h', '1'],
#  ['5h', '25m'],
#  ['5h', '35m'],
#  ['6h', '15m'],
#  ['6h', '40m'],
#  ['6h', '50m'],
#  ['7h', '10m'],
#  ['8h', '30m'],
#  ['8h', '35m'],
#  ['8h', '35m'],
#  ['8h', '40m'],
#  ['8h', '55m'],
#  ['8h', '55m'],
#  ['9h', '25m'],
# ...

# %%
stop4=[]
for i in dur4:
    stop4.append(i.text.split()[2:])
stop4
# Out:
# [['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['1', 'stop', 'at', 'Aurangabad'],
#  ['1', 'stop', 'at', 'Indore'],
#  ['stop', 'at', 'Ahmedabad'],
#  ['1', 'stop', 'at', 'Jammu'],
#  ['1', 'stop', 'at', 'Goa'],
#  ['1', 'stop', 'at', 'Srinagar'],
# ...

# %%
arrtime4=driver.find_elements_by_xpath('//div[@class="_3H-S _1wD5"]')
arrtime4[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="c9bffac2-91d0-4f5b-9786-2602f8f82e7a")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="b310068f-9068-42ad-abd5-4f6b58df1e4d")>]

# %%
arrtimes4=[]
for i in arrtime4:
    arrtimes4.append(i.text.split()[0])
arrtimes4
# Out:
# ['08:05',
#  '23:00',
#  '14:30',
#  '14:05',
#  '00:55',
#  '19:45',
#  '09:40',
#  '12:40',
#  '00:10',
#  '16:55',
#  '18:05',
#  '04:35',
#  '16:35',
#  '09:05',
#  '20:05',
#  '08:00',
#  '14:45',
#  '09:05',
#  '14:10',
#  '20:10',
#  '21:40',
#  '01:40',
#  '08:15',
#  '20:45',
#  '10:40',
#  '16:35',
#  '21:15',
#  '13:10',
#  '22:55',
#  '19:00',
#  '19:25',
#  '18:10',
#  '10:00',
#  '11:40',
#  '09:35',
#  '18:20',
#  '12:20',
#  '22:55',
#  '03:00',
#  '22:00',
#  '19:10',
#  '11:10',
#  '00:10',
#  '16:15',
#  '21:10',
#  '13:20',
#  '11:10',
#  '17:40',
#  '19:00',
#  '18:35',
#  '19:25',
#  '00:15',
#  '13:10',
#  '19:45',
#  '19:45',
#  '20:15',
#  '20:20',
#  '21:10',
#  '22:30',
#  '21:10',
#  '22:20',
#  '18:35',
#  '00:10',
#  '20:20',
#  '08:55',
#  '21:10',
#  '19:25',
#  '20:10',
#  '19:45',
#  '20:15',
#  '21:10',
#  '14:00',
#  '17:45',
#  '13:20',
#  '01:50',
#  '01:50',
#  '08:55',
#  '19:55',
#  '10:55',
#  '08:20',
#  '22:10',
#  '22:10',
#  '08:20',
# ...

# %%
arr4=[]
for i in arrtime4:
    arr4.append(i.text.split()[1])
arr4
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
price4=driver.find_elements_by_xpath('//div[@class="_2gMo"]')
price4[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="7d0f6eba-5e9c-4381-91b8-42b6c3cbe969")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="99bd61ae-f91c-4ea8-a57e-af63fb72980b")>]

# %%
prices4=[]
for i in price4:
    prices4.append(i.text)
prices4
# Out:
# ['8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,703',
# ...

# %%
nextdate=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/div[2]/div/div[1]/div[1]/div/div/div[2]/a[3]')
nextdate
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="1f6ac9c6-74b2-4f2f-8b81-c913ea07766e")>

# %%
nextdate.click()

# %%
airline5=driver.find_elements_by_xpath('//div[@class="_3H-S _1Eia"]')
airline5[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="d7be2d6e-1156-4698-ad30-140b0516359c")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="d226b755-66ff-4091-a3d2-ba23daa7267a")>]

# %%
airlines5=[]
for i in airline5:
    airlines5.append(i.text)
airlines5
# Out:
# ['Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'Air India',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air India',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Air India',
# ...

# %%
len(airlines5)
# Out:
# 218

# %%
deptime5=driver.find_elements_by_xpath('//div[@class="_3Lds _1OV0"]')
deptime5[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="4a700b7d-f727-417a-985f-fa6f481460fa")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="73e6ba57-2600-4bc9-8831-3a25ea5d0d19")>]

# %%
deptimes5=[]
for i in deptime5:
    deptimes5.append(i.text.split()[0])
deptimes5
# Out:
# ['06:00',
#  '06:30',
#  '12:25',
#  '22:45',
#  '11:55',
#  '14:40',
#  '08:45',
#  '10:25',
#  '15:45',
#  '14:35',
#  '07:00',
#  '18:00',
#  '05:55',
#  '07:00',
#  '12:40',
#  '12:05',
#  '00:10',
#  '10:10',
#  '06:05',
#  '08:30',
#  '18:35',
#  '23:30',
#  '13:00',
#  '16:45',
#  '20:40',
#  '22:10',
#  '10:55',
#  '07:45',
#  '17:10',
#  '09:25',
#  '15:55',
#  '07:20',
#  '16:00',
#  '19:35',
#  '00:35',
#  '15:25',
#  '07:20',
#  '19:10',
#  '15:35',
#  '07:05',
#  '07:05',
#  '04:30',
#  '10:05',
#  '10:05',
#  '10:05',
#  '10:50',
#  '07:05',
#  '07:05',
#  '19:35',
#  '07:05',
#  '19:10',
#  '16:45',
#  '15:35',
#  '06:05',
#  '16:45',
#  '20:40',
#  '21:20',
#  '15:40',
#  '07:50',
#  '13:05',
#  '13:05',
#  '13:05',
#  '22:35',
#  '22:35',
#  '06:35',
#  '22:35',
#  '06:35',
#  '18:00',
#  '19:00',
#  '16:00',
#  '21:55',
#  '06:35',
#  '18:15',
#  '19:45',
#  '07:20',
#  '20:55',
#  '19:45',
#  '18:30',
#  '07:30',
#  '20:35',
#  '19:30',
#  '22:00',
#  '21:20',
# ...

# %%
dep5=[]
for i in deptime5:
    dep5.append(i.text.split()[1])
dep5
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
dur5=driver.find_elements_by_xpath('//div[@class="_3zzl _1OV0"]')
dur5[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="5a06aba7-634b-40fa-a4c8-437cfcf0f497")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="55659a65-3702-4b9e-afeb-1c00e78c7413")>]

# %%
durs5=[]
for i in dur5:
    durs5.append(i.text.split()[0:2])
durs5
# Out:
# [['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['2h', 'Non'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['2h', '25m'],
#  ['2h', '25m'],
#  ['3h', '45m'],
#  ['3h', '50m'],
#  ['5h', '1'],
#  ['5h', '35m'],
#  ['6h', '15m'],
#  ['6h', '30m'],
#  ['6h', '40m'],
#  ['8h', '30m'],
#  ['10h', '15m'],
#  ['11h', '5m'],
#  ['11h', '30m'],
#  ['11h', '30m'],
#  ['13h', '15m'],
#  ['13h', '20m'],
#  ['14h', '5m'],
#  ['14h', '30m'],
#  ['20h', '25m'],
#  ['23h', '5m'],
#  ['25h', '20m'],
#  ['26h', '30m'],
# ...

# %%
stop5=[]
for i in dur5:
    stop5.append(i.text.split()[2:])
stop5
# Out:
# [['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['1', 'stop', 'at', 'Aurangabad'],
#  ['1', 'stop', 'at', 'Indore'],
#  ['stop', 'at', 'Ahmedabad'],
#  ['1', 'stop', 'at', 'Goa'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['2', 'Stops', '(SXR,', 'ATQ)'],
#  ['1', 'stop', 'at', 'Srinagar'],
# ...

# %%
arrtime5=driver.find_elements_by_xpath('//div[@class="_3H-S _1wD5"]')
arrtime5[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="52888d71-1d46-433d-a3f7-a0f719254353")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="bb27431a-a797-431d-be5e-cb84da44d440")>]

# %%
arrtimes5=[]
for i in arrtime5:
    arrtimes5.append(i.text.split()[0])
arrtimes5
# Out:
# ['08:05',
#  '08:35',
#  '14:30',
#  '00:55',
#  '14:05',
#  '16:55',
#  '11:00',
#  '12:40',
#  '18:05',
#  '16:35',
#  '09:05',
#  '20:05',
#  '08:00',
#  '09:05',
#  '14:45',
#  '14:10',
#  '02:20',
#  '12:20',
#  '08:15',
#  '10:40',
#  '20:45',
#  '01:40',
#  '15:15',
#  '19:00',
#  '22:55',
#  '00:25',
#  '13:10',
#  '10:00',
#  '19:25',
#  '11:40',
#  '18:10',
#  '09:35',
#  '18:20',
#  '22:00',
#  '03:00',
#  '19:10',
#  '11:10',
#  '00:10',
#  '21:10',
#  '13:20',
#  '13:35',
#  '11:10',
#  '18:35',
#  '20:20',
#  '21:10',
#  '22:20',
#  '18:35',
#  '20:20',
#  '08:55',
#  '21:10',
#  '09:40',
#  '13:10',
#  '14:40',
#  '07:25',
#  '19:15',
#  '01:50',
#  '03:20',
#  '01:50',
#  '19:55',
#  '01:10',
#  '01:20',
#  '03:20',
#  '08:20',
#  '10:25',
#  '22:10',
#  '22:10',
#  '08:20',
#  '20:10',
#  '21:15',
#  '18:20',
#  '00:10',
#  '10:25',
#  '08:20',
#  '21:45',
#  '09:30',
#  '23:00',
#  '21:55',
#  '20:40',
#  '09:40',
#  '22:55',
#  '21:40',
#  '08:55',
#  '08:55',
# ...

# %%
arr5=[]
for i in arrtime5:
    arr5.append(i.text.split()[1])
arr5
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
price5=driver.find_elements_by_xpath('//div[@class="_2gMo"]')
price5[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="d761ff3f-440b-43f5-98c3-97e10063f4a4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="0d91da67-0c52-40c0-9f16-c7d88fefa3c2")>]

# %%
prices5=[]
for i in price5:
    prices5.append(i.text)
prices5
# Out:
# ['8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,778',
#  '8,778',
#  '8,778',
#  '8,884',
#  '9,020',
#  '9,075',
#  '9,124',
#  '9,124',
#  '9,304',
#  '9,304',
#  '9,304',
#  '9,304',
#  '9,408',
#  '9,618',
#  '9,697',
#  '9,697',
# ...

# %%
nextdate=driver.find_element_by_xpath('/html/body/div[1]/div/div[2]/div/div/div/div[2]/div/div[1]/div[1]/div/div/div[2]/a[4]')
nextdate
# Out:
# <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="c13e9353-4edd-46b1-8627-895304a990f0")>

# %%
nextdate.click()

# %%
airline6=driver.find_elements_by_xpath('//div[@class="_3H-S _1Eia"]')
airline6[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="3a7d82f9-2f1b-43ba-a9d1-2258a0401acc")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="61839a15-52d9-49a8-920f-6f7a6c1e3d36")>]

# %%
airlines6=[]
for i in airline6:
    airlines6.append(i.text)
airlines6
# Out:
# ['Air Asia',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'SpiceJet',
#  'Go First',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
#  'Air Asia',
# ...

# %%
deptime6=driver.find_elements_by_xpath('//div[@class="_3Lds _1OV0"]')
deptime6[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="89ed6a13-09f7-4aae-992f-1c475660d515")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="9295a1c9-3081-4a4e-9b49-3297fa4cc643")>]

# %%
deptimes6=[]
for i in deptime6:
    deptimes6.append(i.text.split()[0])
deptimes6
# Out:
# ['13:05',
#  '12:25',
#  '06:00',
#  '06:30',
#  '19:45',
#  '22:45',
#  '14:40',
#  '21:55',
#  '08:45',
#  '15:45',
#  '02:40',
#  '14:35',
#  '05:55',
#  '18:00',
#  '12:05',
#  '07:00',
#  '00:10',
#  '09:55',
#  '18:35',
#  '23:30',
#  '19:30',
#  '06:05',
#  '10:10',
#  '08:30',
#  '16:45',
#  '21:40',
#  '17:10',
#  '15:55',
#  '09:25',
#  '07:45',
#  '07:20',
#  '22:30',
#  '20:35',
#  '16:00',
#  '19:35',
#  '10:50',
#  '10:50',
#  '11:50',
#  '05:50',
#  '10:50',
#  '04:30',
#  '10:50',
#  '10:50',
#  '10:50',
#  '04:30',
#  '10:50',
#  '22:30',
#  '10:50',
#  '10:35',
#  '20:30',
#  '19:35',
#  '06:00',
#  '19:05',
#  '04:30',
#  '05:00',
#  '04:30',
#  '04:30',
#  '04:35',
#  '16:55',
#  '16:45',
#  '14:25',
#  '06:05',
#  '20:40',
#  '21:20',
#  '07:50',
#  '15:40',
#  '22:00',
#  '21:20',
#  '07:50',
#  '13:05',
#  '13:05',
#  '06:35',
#  '22:35',
#  '22:35',
#  '20:00',
#  '20:00',
#  '06:35',
#  '22:35',
#  '06:35',
#  '07:00',
#  '18:00',
#  '19:00',
#  '13:00',
# ...

# %%
dep6=[]
for i in deptime6:
    dep6.append(i.text.split()[1])
dep6
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
dur6=driver.find_elements_by_xpath('//div[@class="_3zzl _1OV0"]')
dur6[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="7f3879b8-54f0-4f0f-9ddf-3405b7fccfce")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="6661f571-1c5d-4c18-8e34-7b291f2f07ee")>]

# %%
durs6=[]
for i in dur6:
    durs6.append(i.text.split()[0:2])
durs6
# Out:
# [['12h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['1h', '55m'],
#  ['2h', 'Non'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '25m'],
#  ['5h', '25m'],
#  ['6h', '50m'],
#  ['7h', '10m'],
#  ['7h', '20m'],
#  ['8h', '35m'],
#  ['8h', '40m'],
#  ['8h', '55m'],
#  ['8h', '55m'],
#  ['9h', '25m'],
#  ['10h', '10m'],
#  ['10h', '20m'],
#  ['11h', '10m'],
#  ['11h', '30m'],
#  ['13h', '1'],
#  ['13h', '10m'],
#  ['13h', '20m'],
#  ['14h', '10m'],
#  ['14h', '55m'],
#  ['14h', '55m'],
#  ['15h', '10m'],
# ...

# %%
stop6=[]
for i in dur6:
    stop6.append(i.text.split()[2:])
stop6
# Out:
# [['2', 'Stops', '(BLR,', 'VTZ)'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['1', 'stop', 'at', 'Jammu'],
#  ['1', 'stop', 'at', 'Jammu'],
#  ['1', 'stop', 'at', 'Kishangarh'],
#  ['1', 'stop', 'at', 'Gorakhpur'],
#  ['2', 'Stops', '(IXJ,', 'SXR)'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['2', 'Stops', '(IXJ,', 'SXR)'],
#  ['2', 'Stops', '(IXJ,', 'SXR)'],
# ...

# %%
arrtime6=driver.find_elements_by_xpath('//div[@class="_3H-S _1wD5"]')
arrtime6[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="411c173d-b274-4b5e-8f72-b5e595b4a1c4")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="b7fcc783-c0c0-4900-973b-fc7209924c65")>]

# %%
arrtimes6=[]
for i in arrtime6:
    arrtimes6.append(i.text.split()[0])
arrtimes6
# Out:
# ['01:10',
#  '14:30',
#  '08:05',
#  '08:35',
#  '21:55',
#  '00:55',
#  '16:55',
#  '00:10',
#  '11:00',
#  '18:05',
#  '04:35',
#  '16:35',
#  '08:00',
#  '20:05',
#  '14:10',
#  '09:05',
#  '02:20',
#  '12:05',
#  '20:45',
#  '01:40',
#  '21:40',
#  '08:15',
#  '12:20',
#  '10:40',
#  '19:00',
#  '23:55',
#  '19:25',
#  '18:10',
#  '11:40',
#  '10:00',
#  '09:35',
#  '00:50',
#  '22:55',
#  '18:20',
#  '22:00',
#  '16:15',
#  '17:40',
#  '19:00',
#  '13:10',
#  '19:25',
#  '13:10',
#  '19:45',
#  '19:45',
#  '20:15',
#  '14:40',
#  '21:10',
#  '09:40',
#  '22:20',
#  '23:35',
#  '09:40',
#  '08:55',
#  '20:10',
#  '10:00',
#  '19:25',
#  '20:10',
#  '19:45',
#  '20:15',
#  '21:10',
#  '10:15',
#  '13:10',
#  '14:00',
#  '07:25',
#  '01:50',
#  '03:20',
#  '14:20',
#  '01:50',
#  '08:55',
#  '08:55',
#  '19:55',
#  '01:20',
#  '03:20',
#  '10:25',
#  '08:20',
#  '10:25',
#  '08:20',
#  '10:25',
#  '22:10',
#  '22:10',
#  '08:20',
#  '09:05',
#  '20:10',
#  '21:15',
#  '15:15',
# ...

# %%
arr6=[]
for i in arrtime6:
    arr6.append(i.text.split()[1])
arr6
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
price6=driver.find_elements_by_xpath('//div[@class="_2gMo"]')
price6[0:2]
# Out:
# [<selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="c65a58bb-e5e2-4f47-936c-12b348fb348d")>,
#  <selenium.webdriver.remote.webelement.WebElement (session="4ccd4aab5b7f17d5d5f5096cad4b5034", element="532a50dc-ecb2-481f-a408-0d00fb722109")>]

# %%
prices6=[]
for i in price6:
    prices6.append(i.text)
prices6
# Out:
# ['8,041',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,567',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,568',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,569',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,703',
#  '8,778',
#  '8,778',
#  '8,778',
#  '8,778',
# ...

# %%
flightname=airlines+airlines1+airlines2+airlines3+airlines4+airlines5+airlines6
flightname
# Out:
# ['IndiGo',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Air Asia',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Go First',
#  'Go First',
#  'Go First',
#  'IndiGo',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'IndiGo',
#  'IndiGo',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'Go First',
#  'Go First',
#  'Go First',
#  'SpiceJet',
#  'Go First',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'SpiceJet',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air India',
#  'Air Asia',
#  'Air Asia',
#  'Vistara',
#  'IndiGo',
#  'Vistara',
#  'Vistara',
#  'Vistara',
#  'Vistara',
# ...

# %%
len(flightname)
# Out:
# 1502

# %%
departuretime=deptimes+deptimes1+deptimes2+deptimes3+deptimes4+deptimes5+deptimes6
departuretime
# Out:
# ['11:55',
#  '21:30',
#  '23:35',
#  '06:30',
#  '10:45',
#  '17:00',
#  '04:25',
#  '14:00',
#  '18:30',
#  '06:00',
#  '15:25',
#  '16:15',
#  '05:30',
#  '14:10',
#  '19:45',
#  '12:50',
#  '20:40',
#  '14:20',
#  '15:30',
#  '22:45',
#  '10:55',
#  '17:45',
#  '08:45',
#  '07:20',
#  '21:40',
#  '19:45',
#  '10:20',
#  '08:00',
#  '16:45',
#  '11:40',
#  '21:45',
#  '09:35',
#  '20:55',
#  '05:55',
#  '06:15',
#  '05:20',
#  '13:35',
#  '06:25',
#  '05:55',
#  '05:00',
#  '06:25',
#  '12:35',
#  '20:30',
#  '05:55',
#  '20:05',
#  '08:45',
#  '18:45',
#  '16:35',
#  '14:50',
#  '16:35',
#  '14:50',
#  '07:00',
#  '20:00',
#  '08:00',
#  '19:00',
#  '14:00',
#  '21:15',
#  '10:00',
#  '15:00',
#  '17:55',
#  '21:40',
#  '09:35',
#  '18:10',
#  '18:10',
#  '05:55',
#  '09:30',
#  '08:50',
#  '21:20',
#  '20:55',
#  '19:45',
#  '17:45',
#  '06:30',
#  '13:00',
#  '07:30',
#  '18:55',
#  '18:10',
#  '06:30',
#  '08:10',
#  '21:20',
#  '18:10',
#  '08:30',
#  '07:20',
#  '12:50',
# ...

# %%
len(departuretime)
# Out:
# 1502

# %%
departurestation=dep+dep1+dep2+dep3+dep4+dep5+dep6
departurestation
# Out:
# ['Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
#  'Delhi',
# ...

# %%
len(departurestation)
# Out:
# 1502

# %%
traveltime=durs+durs1+durs2+durs3+durs4+durs5+durs6
traveltime
# Out:
# [['2h', 'Non'],
#  ['2h', 'Non'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '15m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '20m'],
#  ['2h', '25m'],
#  ['2h', '25m'],
#  ['2h', '30m'],
#  ['4h', '25m'],
#  ['4h', '40m'],
#  ['5h', '25m'],
#  ['6h', '5m'],
#  ['7h', '1'],
#  ['9h', '5m'],
#  ['9h', '20m'],
#  ['9h', '45m'],
#  ['9h', '55m'],
#  ['13h', '35m'],
#  ['13h', '45m'],
#  ['14h', '15m'],
#  ['15h', '10m'],
#  ['16h', '1'],
#  ['21h', '1'],
#  ['22h', '45m'],
#  ['23h', '35m'],
#  ['25h', '20m'],
#  ['2h', '5m'],
#  ['2h', '10m'],
#  ['2h', '10m'],
#  ['2h', '15m'],
# ...

# %%
len(traveltime)
# Out:
# 1502

# %%
stoppage=stop+stop1+stop2+stop3+stop4+stop5+stop6
stoppage
# Out:
# [['Stop'],
#  ['Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['Non', 'Stop'],
#  ['1', 'stop', 'at', 'Ahmedabad'],
#  ['1', 'stop', 'at', 'Jabalpur'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Ahmedabad'],
#  ['stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Ahmedabad'],
#  ['1', 'stop', 'at', 'Amritsar'],
#  ['1', 'stop', 'at', 'Srinagar'],
#  ['1', 'stop', 'at', 'Patna'],
# ...

# %%
len(stoppage)
# Out:
# 1502

# %%
arrivaltime=arrtimes+arrtimes1+arrtimes2+arrtimes3+arrtimes4+arrtimes5+arrtimes6
arrivaltime
# Out:
# ['13:55',
#  '23:30',
#  '01:40',
#  '08:35',
#  '12:50',
#  '19:05',
#  '06:35',
#  '16:10',
#  '20:40',
#  '08:10',
#  '17:35',
#  '18:25',
#  '07:40',
#  '16:20',
#  '21:55',
#  '15:00',
#  '22:50',
#  '16:30',
#  '17:40',
#  '01:00',
#  '13:10',
#  '20:00',
#  '11:00',
#  '09:35',
#  '23:55',
#  '22:00',
#  '12:35',
#  '10:20',
#  '19:05',
#  '14:00',
#  '00:10',
#  '12:00',
#  '23:25',
#  '10:20',
#  '10:55',
#  '10:45',
#  '19:40',
#  '13:25',
#  '15:00',
#  '14:20',
#  '16:10',
#  '22:30',
#  '10:05',
#  '19:40',
#  '10:20',
#  '23:55',
#  '10:45',
#  '13:35',
#  '13:35',
#  '16:10',
#  '16:10',
#  '09:05',
#  '22:10',
#  '10:10',
#  '21:15',
#  '16:15',
#  '23:35',
#  '12:35',
#  '18:15',
#  '22:10',
#  '07:15',
#  '20:40',
#  '06:15',
#  '20:25',
#  '07:55',
#  '11:35',
#  '11:10',
#  '06:15',
#  '09:55',
#  '21:55',
#  '20:05',
#  '06:15',
#  '14:50',
#  '09:45',
#  '21:15',
#  '23:05',
#  '23:05',
#  '20:40',
#  '09:40',
#  '09:40',
#  '15:55',
#  '15:55',
#  '19:15',
# ...

# %%
len(arrivaltime)
# Out:
# 1502

# %%
arrivalstation=arr+arr1+arr2+arr3+arr4+arr5+arr6
arrivalstation
# Out:
# ['Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
#  'Mumbai',
# ...

# %%
len(arrivalstation)
# Out:
# 1502

# %%
flightprices=prices+prices1+prices2+prices3+prices4+prices5+prices6
flightprices
# Out:
# ['8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,579',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,580',
#  '8,581',
#  '8,581',
#  '8,715',
#  '8,789',
#  '8,896',
#  '8,896',
#  '8,896',
#  '9,032',
#  '9,086',
#  '9,316',
#  '9,316',
#  '9,452',
#  '9,661',
#  '9,841',
#  '9,841',
#  '9,977',
#  '9,977',
#  '10,210',
#  '10,502',
#  '10,502',
#  '10,522',
#  '10,522',
# ...

# %%
len(flightprices)
# Out:
# 1502

# %%
flightfile=pd.DataFrame({'Airline Name':flightname,'Departure Timing':departuretime,'Departure Station':departurestation,'Travel Duration':traveltime,'Stoppage Between Stations':stoppage,'Arrival Timing':arrivaltime,'Arrival Station':arrivalstation,'Flight Prices':flightprices})
flightfile
# Out:
#      Airline Name Departure Timing Departure Station Travel Duration  \
# 0          IndiGo            11:55             Delhi       [2h, Non]
# 1         Vistara            21:30             Delhi       [2h, Non]
# 2          IndiGo            23:35             Delhi        [2h, 5m]
# 3          IndiGo            06:30             Delhi        [2h, 5m]
# 4          IndiGo            10:45             Delhi        [2h, 5m]
# ...           ...              ...               ...             ...
# 1497    Air India            06:10            Mumbai        [18h, 1]
# 1498    Air India            09:30            Mumbai       [6h, 10m]
# 1499    Air India            16:40            Mumbai       [7h, 30m]
# 1500    Air India            09:30            Mumbai      [14h, 40m]
# 1501    Air India            17:20            Mumbai      [28h, 50m]
#
#               Stoppage Between Stations Arrival Timing Arrival Station  \
# ...

# %%
flightfile.to_csv('flightprice.csv')

# %% [markdown]
# completed
